# %%
from PIL import Image, ImageOps

# %%
pwd
# Out:
# 'D:\\personal\\Workplace\\GitRepos\\Machine Learning\\MNIST-handwritten'

# %%
img = Image.open('D:\\personal\\Workplace\\GitRepos\\Machine Learning\\MNIST-handwritten\\test\\4_2.jpg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=77x97 at 0x1676A0FC2C8>

# %%
img.show()

# %%
img = img.convert('L')

# %%
img
# Out:
# <PIL.Image.Image image mode=L size=77x97 at 0x1676A9D4988>

# %%
img_inv = ImageOps.invert(img)

# %%
img_inv
# Out:
# <PIL.Image.Image image mode=L size=77x97 at 0x1676A221B48>

# %%
img_2 = Image.open('D:\\personal\\Workplace\\GitRepos\\Machine Learning\\MNIST-handwritten\\test\\img_276.jpg')

# %%
img_2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=28x28 at 0x16769DC24C8>

# %%
type(img_2)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
threshold = 110  
im = img_inv.point(lambda p: p > threshold and 255)

# %%
im
# Out:
# <PIL.Image.Image image mode=L size=77x97 at 0x1676A4D59C8>

# %%
im.size
# Out:
# (77, 97)

# %%
im = im.resize(size=(28, 28))

# %%
im
# Out:
# <PIL.Image.Image image mode=L size=28x28 at 0x1676A5D6B48>

# %%
im.size
# Out:
# (28, 28)

# %%
im.save('D:\\personal\\Workplace\\GitRepos\\Machine Learning\\MNIST-handwritten\\test\\4_2_new.jpg')
